# %%
## Importing relevant libraries

import pandas as pd
import numpy as np

## Stop warnings
import warnings
warnings.filterwarnings('ignore')

# %%
## Loading the data

df = pd.read_csv(r'data\articles_sentiment.csv')
print(df.shape)
df.head()
# Out:
# (142426, 7)
#                                                title  \
# 0  house republicans fret winning health care sui...
# 1  rift officers residents killings persist south...
# 2  tyrus wong bambi artist thwarted racial bias d...
# 3   among deaths heavy toll pop music new york times
# 4  kim jong un says north korea preparing test lo...
#
#                                              content  \
# 0  washington congressional republicans new fear ...
# 1  bullet shells get counted blood dries votive c...
# 2  walt disney bambi opened critics praised spare...
# 3  death may great equalizer necessarily evenhand...
# 4  seoul south korea north korea leader kim said ...
#
#                           author     publication  \
# 0                     Carl Hulse  New York Times
# 1  Benjamin Mueller and Al Baker  New York Times
# 2                   Margalit Fox  New York Times
# 3               William McDonald  New York Times
# 4                  Choe Sang-Hun  New York Times
#
#                                   content_lemmatized sentiment  compound_score
# 0  washington congressional republican new fear c...  positive          0.6497
# 1  bullet shell get counted blood dry votive cand...  negative         -0.9999
# 2  walt disney bambi opened critic praised spare ...  positive          0.9888
# 3  death may great equalizer necessarily evenhand...  negative         -0.8609
# 4  seoul south korea north korea leader kim said ...  positive          0.9789

# %%
## Checking for gendered words in the content column

content = df['content']

print('Occurences of words:')
print('he: ', content.str.contains(' he ').sum())
print('she: ', content.str.contains(' she ').sum())
print('his: ', content.str.contains(' his ').sum())
print('her: ', content.str.contains(' her ').sum())
print('mr: ', content.str.contains(' mr ' or ' mr. ').sum())
print('mrs: ', content.str.contains(' mrs ' or ' mrs. ').sum())
# Out:
# Occurences of words:
# he:  105595
# she:  52130
# his:  95808
# her:  49116
# mr:  13503
# mrs:  2404

# %%
## Listing gendered words

gender_keywords = {'male': [' he ', ' his ', ' him ', ' himself ', ' hes ', ' man ', ' mr. ', ' mr ', ' men '],
                   'female': [' she ', ' her ', ' hers ', ' herself ', ' shes ', ' woman ', ' ms. ', ' ms ', ' mrs. ', ' mrs ', ' women ']}

# %%
## Function to figure out which gender the news article is about

def gender_analysis(text):
    
    # Counting the number of gendered words for male and female
    male_count_keyword = sum(text.count(word) for word in gender_keywords['male'])
    female_count_keyword = sum(text.count(word) for word in gender_keywords['female'])

    # Figuring out the dominating gender by comparing the counts
    # A gender is only considered dominating when it is occured at least 25% more frequent than the less frequent gender
    if male_count_keyword >= 1.25 * female_count_keyword:
        return 'male'
    elif female_count_keyword >= 1.25 * male_count_keyword:
        return 'female'
    else:
        return 'neutral'

# %%
## Applying the function to the content column

df['gender'] = np.nan

for i in range(len(df)):
    df['gender'][i] = gender_analysis(df['content'][i])

df.head()
# Out:
#                                                title  \
# 0  house republicans fret winning health care sui...
# 1  rift officers residents killings persist south...
# 2  tyrus wong bambi artist thwarted racial bias d...
# 3   among deaths heavy toll pop music new york times
# 4  kim jong un says north korea preparing test lo...
#
#                                              content  \
# 0  washington congressional republicans new fear ...
# 1  bullet shells get counted blood dries votive c...
# 2  walt disney bambi opened critics praised spare...
# 3  death may great equalizer necessarily evenhand...
# 4  seoul south korea north korea leader kim said ...
#
#                           author     publication  \
# 0                     Carl Hulse  New York Times
# 1  Benjamin Mueller and Al Baker  New York Times
# 2                   Margalit Fox  New York Times
# 3               William McDonald  New York Times
# 4                  Choe Sang-Hun  New York Times
#
#                                   content_lemmatized sentiment  \
# 0  washington congressional republican new fear c...  positive
# 1  bullet shell get counted blood dry votive cand...  negative
# 2  walt disney bambi opened critic praised spare ...  positive
# 3  death may great equalizer necessarily evenhand...  negative
# 4  seoul south korea north korea leader kim said ...  positive
#
#    compound_score gender
# 0          0.6497   male
# 1         -0.9999   male
# 2          0.9888   male
# 3         -0.8609   male
# 4          0.9789   male

# %%
## gender column value counts

df['gender'].value_counts()
# Out:
# male       109798
# female      26131
# neutral      6497
# Name: gender, dtype: int64

# %%
## saving the data

df.to_csv(r'data\articles_gender.csv', index=False)
